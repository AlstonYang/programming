# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web

df = web.DataReader('AAPL','yahoo',start='2013-1-1',end='2017-1-1')
p = df['Adj Close']
p.plot()

# %%
print(df['Adj Close'].head(10))
print('-'*20)
r = (df['Adj Close'].diff())/df['Adj Close']
# Out:
# Date
# 2012-12-31    66.398476
# 2013-01-02    68.502106
# 2013-01-03    67.637436
# 2013-01-04    65.753418
# 2013-01-07    65.366646
# 2013-01-08    65.542587
# 2013-01-09    64.518211
# 2013-01-10    65.317978
# 2013-01-11    64.917465
# 2013-01-14    62.602997
# Name: Adj Close, dtype: float64
# --------------------

# %%
r[-100:].plot()

# %%
p.plot()
p.rolling(window=20).mean().plot()
p.rolling(window=60).mean().plot()
